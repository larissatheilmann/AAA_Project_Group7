# %% [markdown]
# # Descriptive Analytics - Weather Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# weather data
weather_df = pd.read_parquet("../data/weather_data.parquet")
weather_df
# Out:
#                 time_step    2m_temp  total_precip  snow_cov  snow_depth  \
# 0     2024-01-01 00:00:00  274.39615      0.000281  6.929688    0.007812
# 1     2024-01-01 01:00:00  274.24170      0.000150  8.179688    0.008789
# 2     2024-01-01 02:00:00  274.05762      0.000030  8.804688    0.008789
# 3     2024-01-01 03:00:00  273.90906      0.000014  8.873047    0.008789
# 4     2024-01-01 04:00:00  274.01672      0.000037  8.890625    0.008789
# ...                   ...        ...           ...       ...         ...
# 20707 2026-05-12 19:00:00  293.30435      0.000342  0.000000    0.000000
# 20708 2026-05-12 20:00:00  293.64343      0.000003  0.000000    0.000000
# 20709 2026-05-12 21:00:00  293.37470      0.000053  0.000000    0.000000
# 20710 2026-05-12 22:00:00  292.62510      0.000749  0.000000    0.000000
# 20711 2026-05-12 23:00:00  292.06870      0.000208  0.000000    0.000000
#
#             u10       v10  2m_temp_c  total_precip_mm
# 0      2.705109 -5.971687    1.24615         0.280723
# 1      2.658508 -7.036841    1.09170         0.150489
# 2      2.478607 -7.009237    0.90762         0.030188
# 3      2.442825 -6.861008    0.75906         0.013527
# 4      2.084305 -6.889282    0.86672         0.037491
# ...         ...       ...        ...              ...
# 20707  1.670914  4.648880   20.15435         0.341564
# 20708  1.859116  3.183975   20.49343         0.002533
# 20709  2.806747  3.596573   20.22470         0.052869
# 20710  3.238815  4.192703   19.47510         0.748754
# 20711  3.690521  4.001175   18.91870         0.208199
#
# [20712 rows x 9 columns]

# %%
features = [
    "2m_temp",
    "total_precip",
    "snow_cov",
    "snow_depth",
    "wind_speed"
]

feature_labels = {
    "2m_temp": "2m Temperature",
    "total_precip": "Total Precipitation",
    "snow_cov": "Snow Coverage (%)",
    "snow_depth": "Snow Depth",
    "wind_speed": "Wind Speed"
}

# Mapping of feature and color
colors = {
    "2m_temp": "red",
    "total_precip": "blue",
    "snow_cov": "cyan",
    "snow_depth": "purple",
    "wind_speed": "orange"
}

# %%
n_features = len(features)
fig, axes = plt.subplots(n_features, 1, figsize=(16, 3 * n_features), sharex=True)

for ax, feature in zip(axes, features):
    ax.plot(
        weather_df["time_step"],
        weather_df[feature],
        color=colors[feature],
        label=feature_labels[feature],
        linewidth=1.2
    )
    ax.set_title(feature_labels[feature], fontsize=12)
    ax.set_ylabel("Value")
    ax.legend(loc="upper right")
    ax.grid(True, alpha=0.3)
axes[-1].set_xlabel("Time")
fig.suptitle("Time Series of each Feature", fontsize=18, y=0.995)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wind_speed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 7
#       2 fig, axes = plt.subplots(n_features, 1, figsize=(16, 3 * n_features), sharex=True)
#       4 for ax, feature in zip(axes, features):
#       5     ax.plot(
#       6         weather_df["time_step"],
# ----> 7         weather_df[feature],
#       8         color=colors[feature],
#       9         label=feature_labels[feature],
#      10         linewidth=1.2
#      11     )
#      12     ax.set_title(feature_labels[feature], fontsize=12)
#      13     ax.set_ylabel("Value")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'wind_speed'

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(111, projection="polar")

sc = ax.scatter(
    wind_df["wind_dir_rad"],
    wind_df["wind_speed"],
    c=wind_df["wind_speed"],
    cmap="viridis",
    alpha=0.7,
    s=20
)

ax.set_title("Polarplot von Windrichtung und Windgeschwindigkeit", va="bottom")
cbar = plt.colorbar(sc, pad=0.1)
cbar.set_label("Wind Speed")

plt.show()
