# %% [markdown]
# # Descriptive Analytics - Weather Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# weather data
weather_df = pd.read_parquet("../data/processed/weather_data_processed.parquet")
weather_df
# Out:
#                 time_step    2m_temp  total_precip   snow_cov  snow_depth  \
# 0     2024-01-01 00:00:00  274.39615      0.000281   6.929688    0.007812
# 1     2024-01-01 01:00:00  274.24170      0.000150   8.179688    0.008789
# 2     2024-01-01 02:00:00  274.05762      0.000030   8.804688    0.008789
# 3     2024-01-01 03:00:00  273.90906      0.000014   8.873047    0.008789
# 4     2024-01-01 04:00:00  274.01672      0.000037   8.890625    0.008789
# ...                   ...        ...           ...        ...         ...
# 17539 2025-12-31 19:00:00  275.06760      0.000046  20.257812    0.020508
# 17540 2025-12-31 20:00:00  275.09650      0.000083  20.263672    0.020508
# 17541 2025-12-31 21:00:00  275.02234      0.000160  20.287110    0.020508
# 17542 2025-12-31 22:00:00  274.83923      0.000214  20.525390    0.020508
# 17543 2025-12-31 23:00:00  274.61590      0.000297  20.781250    0.021484
#
#             u10       v10  2m_temp_c  total_precip_mm
# 0      2.705109 -5.971687    1.24615         0.280723
# 1      2.658508 -7.036841    1.09170         0.150489
# 2      2.478607 -7.009237    0.90762         0.030188
# 3      2.442825 -6.861008    0.75906         0.013527
# 4      2.084305 -6.889282    0.86672         0.037491
# ...         ...       ...        ...              ...
# 17539  6.192612  1.700745    1.91760         0.045590
# 17540  6.181183  1.992905    1.94650         0.083260
# 17541  6.444611  1.568558    1.87234         0.160234
# 17542  6.504684  0.508759    1.68923         0.213832
# 17543  5.896606 -1.226120    1.46590         0.297226
#
# [17544 rows x 9 columns]

# %%
features = [
    "2m_temp_c",
    "total_precip_mm",
    "snow_cov",
    "snow_depth"
]

feature_labels = {
    "2m_temp_c": "2m Temperature",
    "total_precip_mm": "Total Precipitation",
    "snow_cov": "Snow Coverage (%)",
    "snow_depth": "Snow Depth"
}

# Mapping of feature and color
colors = {
    "2m_temp_c": "red",
    "total_precip_mm": "blue",
    "snow_cov": "cyan",
    "snow_depth": "purple"
}

# %%
n_features = len(features)
fig, axes = plt.subplots(n_features, 1, figsize=(16, 3 * n_features), sharex=True)

for ax, feature in zip(axes, features):
    ax.plot(
        weather_df["time_step"],
        weather_df[feature],
        color=colors[feature],
        label=feature_labels[feature],
        linewidth=1.2
    )
    ax.set_title(feature_labels[feature], fontsize=12)
    ax.set_ylabel("Value")
    ax.legend(loc="upper right")
    ax.grid(True, alpha=0.3)
axes[-1].set_xlabel("Time")
fig.suptitle("Time Series of each Feature", fontsize=18, y=0.995)
plt.tight_layout()
plt.show()
