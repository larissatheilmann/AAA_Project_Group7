# %%
import pandas as pd
import numpy as np

# %%
# vor dem runterladen der Datei wurde gefiltert:
# - Pickup/Dropoff Census Tract is not null
# - Trip Seconds/Miles is not 0
# - entfernen der Spalten Fare, Tips, Tolls, Extras, Payment Type, Pickup/Dropoff Centroid Location
# übrig sind (16 x 6041177)

taxi_data = pd.read_csv("../data/Taxi_Trips.csv")

# %%
taxi_data
